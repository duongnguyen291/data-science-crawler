# %%
import pandas as pd 
data = pd.read_csv("data_features.csv")

# %%
print(data.info())
print(data.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51973 entries, 0 to 51972
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   comment_text   51973 non-null  object
#  1   like_count     51973 non-null  int64
#  2   reply_count    51973 non-null  int64
#  3   title_youtube  51808 non-null  object
#  4   source_tag     51973 non-null  object
#  5   source_query   51973 non-null  object
#  6   published_at   51973 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 2.8+ MB
# None
#                                         comment_text  like_count  reply_count  \
# 0  💬 Which song touched your heart the most?<br>T...          35            0
# 1                    Karaoke please! So lovely songs           0            0
# 2                      So well explained, thank you.           0            0
# 3  ETERNAL Memory. THIS ALWAYS REMINDS ME OF MY M...           0            0
# ...

# %%
data_test = pd.read_csv(r"D:\code\HUST\data-science-crawler\labeling\labeled_output\labeled_part_1.csv")
print(data_test.info())
print(data_test.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   comment_text   20 non-null     object
#  1   like_count     20 non-null     int64
#  2   reply_count    20 non-null     int64
#  3   title_youtube  20 non-null     object
#  4   source_tag     20 non-null     object
#  5   source_query   20 non-null     object
#  6   published_at   20 non-null     object
#  7   final_label    20 non-null     object
#  8   strategy       20 non-null     object
#  9   margin         2 non-null      float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 1.7+ KB
# None
#                                         comment_text  like_count  reply_count  \
# 0  💬 Which song touched your heart the most?<br>T...          35            0
# 1                    Karaoke please! So lovely songs           0            0
# ...
